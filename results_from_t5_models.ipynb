# %%
import os
import json
import pandas as pd
import re

# Path to the main directory containing subdirectories
main_directory = 'results/models'

# Initialize a list to store data
data = []

# Regex pattern to extract prompt type, epochs, and seed from subdirectory name
pattern = re.compile(r't5-large_prompt_type_(.*?)_epochs_(\d+)_seed_(\d+)')

# Iterate over each subdirectory in the main directory
for subdir in os.listdir(main_directory):
    subdir_path = os.path.join(main_directory, subdir)

    if os.path.isdir(subdir_path):
        metrics_file = os.path.join(subdir_path, 'test_metrics.json')

        # Check if the metrics file exists in the subdirectory
        if os.path.isfile(metrics_file):
            # Load the JSON data
            with open(metrics_file, 'r') as f:
                metrics = json.load(f)

            # Extract prompt type, epochs, and seed using regex
            match = pattern.match(subdir)
            if match:
                prompt_type = match.group(1)
                epochs = int(match.group(2))
                seed = int(match.group(3))

                # Add the data to the list
                data.append({
                    'subdirectory': subdir,
                    'prompt_type': prompt_type,
                    'epochs': epochs,
                    'seed': seed,
                    'f1': metrics.get('f1'),
                    'precision': metrics.get('precision'),
                    'recall': metrics.get('recall'),
                    'accuracy': metrics.get('accuracy')
                })

# Create a DataFrame from the collected data
raw_data = pd.DataFrame(data)

# Display the DataFrame
raw_data
# Out:
#                                          subdirectory  \
# 0   t5-large_prompt_type_with_fallacy_definition_e...
# 1   t5-large_prompt_type_with_fallacy_definition_e...
# 2   t5-large_prompt_type_with_fallacy_definition_e...
# 3   t5-large_prompt_type_with_fallacy_definition_e...
# 4   t5-large_prompt_type_with_fallacy_definition_e...
# 5   t5-large_prompt_type_with_fallacy_definition_e...
# 6   t5-large_prompt_type_with_fallacy_definition_w...
# 7   t5-large_prompt_type_with_fallacy_definition_w...
# 8   t5-large_prompt_type_with_fallacy_definition_w...
# 9   t5-large_prompt_type_with_fallacy_definition_w...
# 10  t5-large_prompt_type_with_fallacy_definition_w...
# 11  t5-large_prompt_type_with_fallacy_definition_w...
# 12  t5-large_prompt_type_without_fallacy_definitio...
# 13  t5-large_prompt_type_without_fallacy_definitio...
# 14  t5-large_prompt_type_without_fallacy_definitio...
# 15  t5-large_prompt_type_without_fallacy_definitio...
# 16  t5-large_prompt_type_without_fallacy_definitio...
# 17  t5-large_prompt_type_without_fallacy_definitio...
# 18  t5-large_prompt_type_without_fallacy_definitio...
# 19  t5-large_prompt_type_without_fallacy_definitio...
# 20  t5-large_prompt_type_without_fallacy_definitio...
# 21  t5-large_prompt_type_without_fallacy_definitio...
# 22  t5-large_prompt_type_without_fallacy_definitio...
# 23  t5-large_prompt_type_without_fallacy_definitio...
#
#                              prompt_type  epochs  seed        f1  precision  \
# 0                with_fallacy_definition      50   183  0.113541   0.094208
# 1                with_fallacy_definition      50    64  0.113541   0.094208
# 2                with_fallacy_definition      50    98  0.113541   0.094208
# 3                with_fallacy_definition       5   183  0.016131   0.068132
# 4                with_fallacy_definition       5    64  0.005013   0.011905
# 5                with_fallacy_definition       5    98  0.010485   0.033613
# 6      with_fallacy_definition_with_NotA      50   183  0.113541   0.094208
# 7      with_fallacy_definition_with_NotA      50    64  0.113541   0.094208
# 8      with_fallacy_definition_with_NotA      50    98  0.113541   0.094208
# 9      with_fallacy_definition_with_NotA       5   183  0.003072   0.142857
# 10     with_fallacy_definition_with_NotA       5    64  0.003784   0.119048
# 11     with_fallacy_definition_with_NotA       5    98  0.000000   0.000000
# 12            without_fallacy_definition      50   183  0.154924   0.240151
# 13            without_fallacy_definition      50    64  0.168890   0.316064
# 14            without_fallacy_definition      50    98  0.153216   0.433294
# 15            without_fallacy_definition       5   183  0.063214   0.180013
# 16            without_fallacy_definition       5    64  0.056776   0.038065
# 17            without_fallacy_definition       5    98  0.021429   0.013975
# 18  without_fallacy_definition_with_NotA      50   183  0.160239   0.470564
# 19  without_fallacy_definition_with_NotA      50    64  0.199160   0.230190
# 20  without_fallacy_definition_with_NotA      50    98  0.120052   0.152208
# 21  without_fallacy_definition_with_NotA       5   183  0.113541   0.094208
# 22  without_fallacy_definition_with_NotA       5    64  0.113541   0.094208
# 23  without_fallacy_definition_with_NotA       5    98  0.113541   0.094208
#
#       recall  accuracy
# 0   0.142857  0.659459
# 1   0.142857  0.659459
# 2   0.142857  0.659459
# 3   0.009386  0.003604
# 4   0.003175  0.000000
# 5   0.006211  0.001802
# 6   0.142857  0.659459
# 7   0.142857  0.659459
# 8   0.142857  0.659459
# 9   0.001553  0.000000
# 10  0.001943  0.001802
# 11  0.000000  0.000000
# 12  0.166104  0.661261
# 13  0.172122  0.652252
# 14  0.163303  0.657658
# 15  0.131056  0.072072
# 16  0.115834  0.057658
# 17  0.045918  0.007207
# 18  0.168039  0.664865
# 19  0.199803  0.657658
# 20  0.145963  0.661261
# 21  0.142857  0.659459
# 22  0.142857  0.659459
# 23  0.142857  0.659459

# %%
raw_data.dtypes
# Out:
# subdirectory     object
# prompt_type      object
# epochs            int64
# seed              int64
# f1              float64
# precision       float64
# recall          float64
# accuracy        float64
# dtype: object

# %%
summary_data = raw_data \
    .drop(columns=['seed', 'subdirectory']) \
    .groupby(['prompt_type', 'epochs']).mean() \
    .reset_index() \
    .sort_values(by='f1', ascending=False)
summary_data
# Out:
#                             prompt_type  epochs        f1  precision  \
# 7  without_fallacy_definition_with_NotA      50  0.159817   0.284321
# 5            without_fallacy_definition      50  0.159010   0.329836
# 1               with_fallacy_definition      50  0.113541   0.094208
# 3     with_fallacy_definition_with_NotA      50  0.113541   0.094208
# 6  without_fallacy_definition_with_NotA       5  0.113541   0.094208
# 4            without_fallacy_definition       5  0.047139   0.077351
# 0               with_fallacy_definition       5  0.010543   0.037883
# 2     with_fallacy_definition_with_NotA       5  0.002285   0.087302
#
#      recall  accuracy
# 7  0.171268  0.661261
# 5  0.167176  0.657057
# 1  0.142857  0.659459
# 3  0.142857  0.659459
# 6  0.142857  0.659459
# 4  0.097603  0.045646
# 0  0.006257  0.001802
# 2  0.001165  0.000601

# %% [markdown]
# Models of 50 epochs are better than models of 5 (which is totally expected, this is more of a sanity check).
# Models that don't include the fallacy definitions in their prompt perform better.
# Adding the comment of the None of the above class in the prompt doesn't improve much the performance.
